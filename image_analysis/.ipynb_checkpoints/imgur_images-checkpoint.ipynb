# %%
# !pip install imgur-downloader

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import numpy as np
import imgur_downloader

# %%
dank_df = pd.read_csv("../Data/dank_removed_deadLinks.csv")

# %%
with open("../Data/imgurID.log", "r") as infile:
    imgurLinks = infile.readlines()

# %%
imgur_downloader.ImgurDownloader(
    'https://imgur.com/gallery/gPpzo5n', '../Images/','sampleImage',delete_dne=True, debug=True
).save_images()
# Out:
# imgur_link_type: gallery/
# main key: gPpzo5n
# album_title: sampleImage
# imageIDs count: 1
# imageIDs:
# [('jx5PIjV', '.jpg')]
# ([], 1)

# %%
dank_df['media'][dank_df['id'] == imgurLinks[0].strip('\n')].values[0]
# Out:
# 'https://i.imgur.com/pQ3pQld.jpg'

# %%
imgur_downloader.ImgurDownloader(
    dank_df['media'][dank_df['id'] == imgurLinks[0].strip('\n')].values[0], '../Imgur/','image_1',delete_dne=True, debug=True
).save_images()
# Out:
# imgur_link_type: None
# main key: pQ3pQld
# ([], 1)

# %%
for index_one, ID in enumerate(imgurLinks):
    for index_two, val in enumerate(dank_df['media'][dank_df['id'] == ID.strip('\n')].values):
        f_name = 'image_'+str(index_one)+'.'+str(index_two)
        try:
            imgur_downloader.ImgurDownloader(
                val, '../Imgur/',f_name,delete_dne=True, debug=True
            ).save_images()
        except:
            continue
# Out:
# imgur_link_type: None
# main key: pQ3pQld
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: YBkvk3E
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: HeDOM7I
# album_title: image_2.0
# imageIDs count: 1
# imageIDs:
# [('HeDOM7I', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: uPyHgVl
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: GyuMcy2
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: VNU8zZn
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: pHvK3CE
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: uYbyE51
# album_title: image_7.0
# imageIDs count: 1
# imageIDs:
# [('uYbyE51', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: rK8G3lT
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: rK8G3lT
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: 8vNhBsD
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: 8vNhBsD
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: bM078mI
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: 0cEPMhy
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: IKum2AA
# album_title: image_12.0
# imageIDs count: 1
# imageIDs:
# [('IKum2AA', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: BO7NGyW
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: hRc5QLV
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: DIBqaz8
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: PM7Vels
# album_title: image_16.0
# imageIDs count: 1
# imageIDs:
# [('PM7Vels', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: a/
# main key: 6c5isJc
# album_title: image_17.0
# imageIDs count: 1
# imageIDs:
# [('MD0PxGn', '.png')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: Pr7Ntap
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: Pr7Ntap
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: miJ2Gts
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: kFVlMIu
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: E3UqyAd
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: Mz99KRr
# album_title: image_22.0
# imageIDs count: 1
# imageIDs:
# [('Mz99KRr', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: diVayMh
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: 5eW0YIT
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: WINVmUT
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: VwpRHQa
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: w5xcFby
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: gallery/
# main key: 4aTpSXp
# album_title: image_28.0
# imageIDs count: 1
# imageIDs:
# [('3kdXJBS', '.png')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: cEfqN5S
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: IWoV5Dz
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: iYpv7EF
# album_title: image_31.0
# imageIDs count: 1
# imageIDs:
# [('iYpv7EF', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: 9ASUZ7T
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: 9ASUZ7T
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: F5q5pF6
# album_title: image_33.0
# imageIDs count: 1
# imageIDs:
# [('F5q5pF6', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: F5q5pF6
# album_title: image_33.1
# imageIDs count: 1
# imageIDs:
# [('F5q5pF6', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: gallery/
# main key: YEcBZcr
# album_title: image_34.0
# imageIDs count: 1
# imageIDs:
# [('Q6zjPaD', '.mp4')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: PE1EDsK
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: kk0nYDx
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: L1lbB4q
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: vuim8rM
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: lFZ9FJD
# album_title: image_39.0
# imageIDs count: 1
# imageIDs:
# [('lFZ9FJD', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: NE97kLU
# album_title: image_40.0
# imageIDs count: 1
# imageIDs:
# [('NE97kLU', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: HeOsEKL
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: jDXXKUw
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: hx4H8Z9
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: hx4H8Z9
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: NzAQsnz
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: A7RssZI
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: ArU5alN
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: RpTHfwt
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: qoSAuHQ
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: eG35PYJ
# album_title: image_49.0
# imageIDs count: 1
# imageIDs:
# [('eG35PYJ', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: QSuKT2g
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: e5pyVHB
# album_title: image_51.0
# imageIDs count: 1
# imageIDs:
# [('e5pyVHB', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: SeJesLc
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: SeJesLc
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: kHojabv
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: YpT72fx
# album_title: image_54.0
# imageIDs count: 1
# imageIDs:
# [('YpT72fx', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: SOEwBS1
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: 4JYfdYM
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: A6breZg
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: IMieGsz
# album_title: image_58.0
# imageIDs count: 1
# imageIDs:
# [('IMieGsz', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: oTQhEpt
# album_title: image_59.0
# imageIDs count: 1
# imageIDs:
# [('oTQhEpt', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: a/
# main key: Kn0MXEl
# album_title: image_60.0
# imageIDs count: 1
# imageIDs:
# [('fROHQ85', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: pEPuL5t
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: bd5RsB9
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: m3LmazD
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: DaZSUIE
# album_title: image_64.0
# imageIDs count: 1
# imageIDs:
# [('DaZSUIE', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: Fzq1dxx
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: eg7UYhP
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: 8jIDMpN
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: e5jf3nY
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: KVAN54s
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: 14MLmqq
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: gRrMYzy
# album_title: image_71.0
# imageIDs count: 1
# imageIDs:
# [('gRrMYzy', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: pl0SCR3
# album_title: image_72.0
# imageIDs count: 1
# imageIDs:
# [('pl0SCR3', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: qYhDkN6
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: 9cJqX7W
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: s7yc0ks
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: s7yc0ks
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: Sc3rML9
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: DotIUrX
# album_title: image_77.0
# imageIDs count: 1
# imageIDs:
# [('DotIUrX', '.jpg')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: lJzETtM
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: qMZeVZq
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: None
# main key: sJQS8lw
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: a/
# main key: 0wqBO9b
# album_title: image_81.0
# imageIDs count: 1
# imageIDs:
# [('GPWQ4Su', '.png')]
# [ImgurDownloader] Warning: DNE image not found at C:\Users\tiern\anaconda3\lib\site-packages\imgur_downloader\imgur-dne.png
# imgur_link_type: gallery/
# main key: MCAeVSP
# ---------------------------------------------------------------------------
# ImgurException                            Traceback (most recent call last)
# <ipython-input-8-0f68e3815768> in <module>
#       3         f_name = 'image_'+str(index_one)+'.'+str(index_two)
#       4         imgur_downloader.ImgurDownloader(
# ----> 5             val, '../Imgur/',f_name,delete_dne=True, debug=True
#       6         ).save_images()
#
# ~\anaconda3\lib\site-packages\imgur_downloader\imgurdownloader.py in __init__(self, imgur_url, dir_download, file_name, delete_dne, debug)
#     134         if not self.response or self.response.getcode() != 200:
#     135             raise ImgurException("[ImgurDownloader] HTTP Response Code %d"
# --> 136                                  % response_code)
#     137
#     138         # Read in the images now so we can get stats and stuff:
#
# ImgurException: [ImgurDownloader] HTTP Response Code 404
